# %% [markdown]
# <a href="https://colab.research.google.com/github/JPedroSilveira/deep_learning/blob/main/Understanding_Deep_Learning/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 204 (delta 47), reused 60 (delta 41), pack-reused 128
# Receiving objects: 100% (204/204), 8.42 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero? By around half of the total epoches (500)
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? 200
# 3. At what capacity do you expect the maximum of the double descent curve to appear? 800

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.297400, train error 88.65,  test loss 2.297986, test error 88.45
# Epoch   100, train loss 1.927478, train error 72.03,  test loss 1.773440, test error 69.50
# Epoch   200, train loss 1.921886, train error 72.05,  test loss 1.739161, test error 68.93
# Epoch   300, train loss 1.915071, train error 70.43,  test loss 1.737624, test error 67.93
# Epoch   400, train loss 1.913377, train error 70.65,  test loss 1.737276, test error 68.05
# Epoch   500, train loss 1.913349, train error 70.32,  test loss 1.734856, test error 67.80
# Epoch   600, train loss 1.914114, train error 70.72,  test loss 1.733322, test error 69.05
# Epoch   700, train loss 1.909485, train error 70.68,  test loss 1.738722, test error 67.80
# Epoch   800, train loss 1.911229, train error 70.82,  test loss 1.745831, test error 68.18
# Epoch   900, train loss 1.911963, train error 71.22,  test loss 1.735167, test error 68.12
# Training model with   4 hidden variables
# Epoch     0, train loss 2.303272, train error 90.93,  test loss 2.301646, test error 90.97
# Epoch   100, train loss 1.788381, train error 65.12,  test loss 1.618991, test error 63.28
# Epoch   200, train loss 1.779193, train error 65.10,  test loss 1.596635, test error 63.15
# Epoch   300, train loss 1.775139, train error 64.55,  test loss 1.587810, test error 62.38
# Epoch   400, train loss 1.772537, train error 64.88,  test loss 1.592002, test error 62.35
# Epoch   500, train loss 1.769717, train error 64.57,  test loss 1.592829, test error 62.62
# Epoch   600, train loss 1.769490, train error 64.85,  test loss 1.592265, test error 62.30
# Epoch   700, train loss 1.768888, train error 64.70,  test loss 1.597688, test error 62.05
# Epoch   800, train loss 1.772472, train error 64.93,  test loss 1.596848, test error 62.28
# Epoch   900, train loss 1.768342, train error 64.82,  test loss 1.598213, test error 62.35
# Training model with   6 hidden variables
# Epoch     0, train loss 2.282150, train error 87.90,  test loss 2.285763, test error 88.50
# Epoch   100, train loss 1.704465, train error 59.88,  test loss 1.497451, test error 56.88
# Epoch   200, train loss 1.661028, train error 58.03,  test loss 1.475124, test error 56.47
# Epoch   300, train loss 1.645941, train error 57.62,  test loss 1.468436, test error 55.67
# Epoch   400, train loss 1.639474, train error 57.53,  test loss 1.470662, test error 55.12
# Epoch   500, train loss 1.637892, train error 57.47,  test loss 1.480677, test error 56.55
# Epoch   600, train loss 1.641930, train error 57.38,  test loss 1.493278, test error 56.53
# Epoch   700, train loss 1.634357, train error 57.70,  test loss 1.490365, test error 56.53
# Epoch   800, train loss 1.631995, train error 56.90,  test loss 1.484849, test error 55.72
# Epoch   900, train loss 1.629585, train error 57.10,  test loss 1.481117, test error 55.62
# Training model with   8 hidden variables
# Epoch     0, train loss 2.275277, train error 86.18,  test loss 2.251996, test error 86.12
# Epoch   100, train loss 1.568761, train error 53.25,  test loss 1.403445, test error 51.95
# Epoch   200, train loss 1.525553, train error 51.80,  test loss 1.380063, test error 51.17
# Epoch   300, train loss 1.505194, train error 51.25,  test loss 1.374423, test error 51.40
# Epoch   400, train loss 1.502807, train error 51.28,  test loss 1.375213, test error 50.35
# Epoch   500, train loss 1.498137, train error 51.30,  test loss 1.375041, test error 50.78
# Epoch   600, train loss 1.497131, train error 51.72,  test loss 1.371370, test error 50.38
# Epoch   700, train loss 1.501489, train error 52.05,  test loss 1.386470, test error 50.90
# Epoch   800, train loss 1.494615, train error 51.50,  test loss 1.389772, test error 50.92
# Epoch   900, train loss 1.493908, train error 52.10,  test loss 1.391886, test error 51.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.249218, train error 84.85,  test loss 2.232975, test error 84.07
# Epoch   100, train loss 1.615228, train error 57.72,  test loss 1.474547, test error 57.35
# Epoch   200, train loss 1.536285, train error 54.12,  test loss 1.445795, test error 55.90
# Epoch   300, train loss 1.491146, train error 52.25,  test loss 1.429379, test error 53.65
# Epoch   400, train loss 1.461232, train error 49.80,  test loss 1.398885, test error 52.08
# Epoch   500, train loss 1.436519, train error 48.58,  test loss 1.379732, test error 51.28
# Epoch   600, train loss 1.426728, train error 48.72,  test loss 1.383353, test error 51.67
# Epoch   700, train loss 1.415794, train error 48.80,  test loss 1.384001, test error 50.97
# Epoch   800, train loss 1.413723, train error 48.70,  test loss 1.404561, test error 52.12
# Epoch   900, train loss 1.411311, train error 48.53,  test loss 1.401608, test error 51.33
# Training model with  14 hidden variables
# Epoch     0, train loss 2.182260, train error 79.65,  test loss 2.148237, test error 78.80
# Epoch   100, train loss 1.419919, train error 46.83,  test loss 1.286543, test error 47.88
# Epoch   200, train loss 1.354990, train error 45.92,  test loss 1.304358, test error 49.42
# Epoch   300, train loss 1.318063, train error 44.60,  test loss 1.306365, test error 48.92
# Epoch   400, train loss 1.298707, train error 43.90,  test loss 1.324840, test error 48.97
# Epoch   500, train loss 1.287809, train error 43.12,  test loss 1.329680, test error 49.25
# Epoch   600, train loss 1.283638, train error 42.88,  test loss 1.334741, test error 48.90
# Epoch   700, train loss 1.275420, train error 43.08,  test loss 1.364335, test error 49.72
# Epoch   800, train loss 1.264429, train error 43.10,  test loss 1.371774, test error 49.47
# Epoch   900, train loss 1.262814, train error 42.50,  test loss 1.383176, test error 49.67
# Training model with  18 hidden variables
# Epoch     0, train loss 2.243519, train error 82.75,  test loss 2.232403, test error 83.55
# Epoch   100, train loss 1.402204, train error 46.25,  test loss 1.352725, test error 51.03
# Epoch   200, train loss 1.285051, train error 42.80,  test loss 1.332540, test error 49.17
# Epoch   300, train loss 1.221598, train error 40.80,  test loss 1.356754, test error 49.83
# Epoch   400, train loss 1.181975, train error 38.55,  test loss 1.390562, test error 49.95
# Epoch   500, train loss 1.161600, train error 38.45,  test loss 1.444274, test error 50.47
# Epoch   600, train loss 1.151049, train error 38.78,  test loss 1.474013, test error 51.08
# Epoch   700, train loss 1.140144, train error 38.05,  test loss 1.486744, test error 50.30
# Epoch   800, train loss 1.136321, train error 38.08,  test loss 1.527305, test error 51.50
# Epoch   900, train loss 1.136071, train error 37.83,  test loss 1.548117, test error 51.17
# Training model with  22 hidden variables
# Epoch     0, train loss 2.210593, train error 81.53,  test loss 2.196853, test error 81.03
# Epoch   100, train loss 1.272015, train error 41.95,  test loss 1.324039, test error 49.22
# Epoch   200, train loss 1.148786, train error 38.08,  test loss 1.400061, test error 49.60
# Epoch   300, train loss 1.074495, train error 37.15,  test loss 1.467782, test error 50.42
# Epoch   400, train loss 1.042593, train error 34.95,  test loss 1.549521, test error 51.22
# Epoch   500, train loss 1.025675, train error 34.80,  test loss 1.607905, test error 51.50
# Epoch   600, train loss 1.004825, train error 33.85,  test loss 1.650548, test error 51.88
# Epoch   700, train loss 0.996469, train error 33.85,  test loss 1.700766, test error 52.08
# Epoch   800, train loss 0.973428, train error 33.50,  test loss 1.720311, test error 52.55
# Epoch   900, train loss 0.964373, train error 32.90,  test loss 1.779654, test error 52.70
# Training model with  26 hidden variables
# Epoch     0, train loss 2.089007, train error 79.30,  test loss 2.018846, test error 77.65
# Epoch   100, train loss 1.241911, train error 39.35,  test loss 1.327070, test error 48.58
# Epoch   200, train loss 1.091058, train error 35.05,  test loss 1.433213, test error 49.75
# Epoch   300, train loss 1.012667, train error 32.85,  test loss 1.571685, test error 51.00
# Epoch   400, train loss 0.952661, train error 31.30,  test loss 1.663241, test error 50.85
# Epoch   500, train loss 0.917458, train error 29.32,  test loss 1.758667, test error 51.97
# Epoch   600, train loss 0.888651, train error 29.60,  test loss 1.858488, test error 52.62
# Epoch   700, train loss 0.897865, train error 30.15,  test loss 1.970301, test error 53.17
# Epoch   800, train loss 0.859261, train error 28.75,  test loss 2.037636, test error 53.00
# Epoch   900, train loss 0.856257, train error 27.95,  test loss 2.122967, test error 53.58
# Training model with  30 hidden variables
# Epoch     0, train loss 2.234666, train error 82.10,  test loss 2.220630, test error 81.35
# Epoch   100, train loss 1.129604, train error 37.03,  test loss 1.399574, test error 51.33
# Epoch   200, train loss 0.963562, train error 31.88,  test loss 1.625903, test error 52.75
# Epoch   300, train loss 0.881962, train error 30.25,  test loss 1.819246, test error 54.03
# Epoch   400, train loss 0.803459, train error 26.75,  test loss 2.033462, test error 56.15
# Epoch   500, train loss 0.768533, train error 26.57,  test loss 2.199760, test error 56.72
# Epoch   600, train loss 0.736151, train error 24.40,  test loss 2.330509, test error 55.05
# Epoch   700, train loss 0.716575, train error 24.28,  test loss 2.518444, test error 57.05
# Epoch   800, train loss 0.699968, train error 24.40,  test loss 2.680015, test error 57.05
# Epoch   900, train loss 0.698552, train error 24.50,  test loss 2.808786, test error 57.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.157242, train error 80.93,  test loss 2.121650, test error 80.57
# Epoch   100, train loss 1.058517, train error 34.90,  test loss 1.419154, test error 51.30
# Epoch   200, train loss 0.800932, train error 26.93,  test loss 1.705184, test error 52.40
# Epoch   300, train loss 0.656680, train error 22.60,  test loss 2.082077, test error 54.65
# Epoch   400, train loss 0.582990, train error 19.90,  test loss 2.450981, test error 54.70
# Epoch   500, train loss 0.575599, train error 19.75,  test loss 2.801652, test error 54.30
# Epoch   600, train loss 0.522813, train error 18.28,  test loss 3.188982, test error 55.42
# Epoch   700, train loss 0.470239, train error 16.30,  test loss 3.533964, test error 56.10
# Epoch   800, train loss 0.435039, train error 15.35,  test loss 3.796292, test error 55.40
# Epoch   900, train loss 0.414807, train error 14.95,  test loss 4.165115, test error 57.22
# Training model with  40 hidden variables
# Epoch     0, train loss 2.132580, train error 79.55,  test loss 2.088198, test error 78.62
# Epoch   100, train loss 0.920402, train error 30.25,  test loss 1.454180, test error 49.17
# Epoch   200, train loss 0.608927, train error 19.30,  test loss 2.063473, test error 53.38
# Epoch   300, train loss 0.472785, train error 15.90,  test loss 2.747993, test error 54.15
# Epoch   400, train loss 0.392267, train error 13.47,  test loss 3.446973, test error 54.92
# Epoch   500, train loss 0.320556, train error 10.93,  test loss 4.290927, test error 55.83
# Epoch   600, train loss 0.304725, train error 10.45,  test loss 5.094714, test error 56.90
# Epoch   700, train loss 0.293507, train error 10.28,  test loss 5.747115, test error 57.78
# Epoch   800, train loss 0.230043, train error 8.12,  test loss 6.422169, test error 56.65
# Epoch   900, train loss 0.289967, train error 10.82,  test loss 6.845462, test error 56.50
# Training model with  45 hidden variables
# Epoch     0, train loss 2.102452, train error 79.62,  test loss 2.058199, test error 77.93
# Epoch   100, train loss 0.807585, train error 26.28,  test loss 1.522718, test error 50.33
# Epoch   200, train loss 0.494335, train error 15.93,  test loss 2.389326, test error 55.75
# Epoch   300, train loss 0.318923, train error 10.12,  test loss 3.459756, test error 56.92
# Epoch   400, train loss 0.266149, train error 9.50,  test loss 4.637176, test error 57.85
# Epoch   500, train loss 0.157890, train error 4.80,  test loss 5.882975, test error 57.08
# Epoch   600, train loss 0.202670, train error 7.50,  test loss 7.224062, test error 56.80
# Epoch   700, train loss 0.129219, train error 4.57,  test loss 8.293503, test error 57.00
# Epoch   800, train loss 0.008390, train error 0.00,  test loss 9.151624, test error 57.00
# Epoch   900, train loss 0.005884, train error 0.00,  test loss 9.703335, test error 56.95
# Training model with  50 hidden variables
# Epoch     0, train loss 2.083477, train error 77.62,  test loss 2.047047, test error 77.70
# Epoch   100, train loss 0.747302, train error 24.03,  test loss 1.547896, test error 50.25
# Epoch   200, train loss 0.352480, train error 9.78,  test loss 2.588985, test error 54.15
# Epoch   300, train loss 0.151590, train error 3.10,  test loss 4.083280, test error 54.58
# Epoch   400, train loss 0.040990, train error 0.05,  test loss 5.735604, test error 55.12
# Epoch   500, train loss 0.014557, train error 0.00,  test loss 6.715259, test error 55.42
# Epoch   600, train loss 0.009008, train error 0.00,  test loss 7.371126, test error 55.50
# Epoch   700, train loss 0.006369, train error 0.00,  test loss 7.856873, test error 55.50
# Epoch   800, train loss 0.004841, train error 0.00,  test loss 8.240841, test error 55.53
# Epoch   900, train loss 0.003909, train error 0.00,  test loss 8.554595, test error 55.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.060405, train error 75.80,  test loss 2.004426, test error 76.20
# Epoch   100, train loss 0.636029, train error 19.55,  test loss 1.703573, test error 53.28
# Epoch   200, train loss 0.220145, train error 5.07,  test loss 3.085860, test error 55.50
# Epoch   300, train loss 0.047272, train error 0.10,  test loss 4.991899, test error 56.38
# Epoch   400, train loss 0.015073, train error 0.00,  test loss 6.096767, test error 56.15
# Epoch   500, train loss 0.008681, train error 0.00,  test loss 6.774237, test error 56.40
# Epoch   600, train loss 0.005913, train error 0.00,  test loss 7.261259, test error 56.42
# Epoch   700, train loss 0.004435, train error 0.00,  test loss 7.645461, test error 56.47
# Epoch   800, train loss 0.003519, train error 0.00,  test loss 7.951993, test error 56.42
# Epoch   900, train loss 0.002877, train error 0.00,  test loss 8.212597, test error 56.47
# Training model with  60 hidden variables
# Epoch     0, train loss 2.046384, train error 76.80,  test loss 1.967454, test error 75.62
# Epoch   100, train loss 0.537074, train error 15.45,  test loss 1.759645, test error 51.58
# Epoch   200, train loss 0.099836, train error 0.75,  test loss 3.459466, test error 54.92
# Epoch   300, train loss 0.019465, train error 0.00,  test loss 4.790162, test error 55.38
# Epoch   400, train loss 0.009263, train error 0.00,  test loss 5.492609, test error 55.45
# Epoch   500, train loss 0.005854, train error 0.00,  test loss 5.955052, test error 55.55
# Epoch   600, train loss 0.004211, train error 0.00,  test loss 6.290691, test error 55.45
# Epoch   700, train loss 0.003239, train error 0.00,  test loss 6.558397, test error 55.42
# Epoch   800, train loss 0.002603, train error 0.00,  test loss 6.784046, test error 55.42
# Epoch   900, train loss 0.002165, train error 0.00,  test loss 6.970344, test error 55.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.022033, train error 75.45,  test loss 1.947680, test error 75.82
# Epoch   100, train loss 0.402224, train error 10.93,  test loss 2.013507, test error 52.92
# Epoch   200, train loss 0.037208, train error 0.00,  test loss 3.667565, test error 53.58
# Epoch   300, train loss 0.011546, train error 0.00,  test loss 4.515687, test error 53.70
# Epoch   400, train loss 0.006392, train error 0.00,  test loss 4.980182, test error 53.67
# Epoch   500, train loss 0.004271, train error 0.00,  test loss 5.302082, test error 53.88
# Epoch   600, train loss 0.003158, train error 0.00,  test loss 5.545600, test error 53.92
# Epoch   700, train loss 0.002478, train error 0.00,  test loss 5.741230, test error 53.90
# Epoch   800, train loss 0.002024, train error 0.00,  test loss 5.902001, test error 53.92
# Epoch   900, train loss 0.001700, train error 0.00,  test loss 6.044450, test error 54.08
# Training model with  80 hidden variables
# Epoch     0, train loss 2.032963, train error 75.10,  test loss 1.979335, test error 75.55
# Epoch   100, train loss 0.250880, train error 5.18,  test loss 2.173459, test error 52.65
# Epoch   200, train loss 0.020128, train error 0.00,  test loss 3.580665, test error 53.83
# Epoch   300, train loss 0.008142, train error 0.00,  test loss 4.153038, test error 54.00
# Epoch   400, train loss 0.004831, train error 0.00,  test loss 4.499095, test error 54.58
# Epoch   500, train loss 0.003338, train error 0.00,  test loss 4.741390, test error 54.60
# Epoch   600, train loss 0.002514, train error 0.00,  test loss 4.931909, test error 54.67
# Epoch   700, train loss 0.001997, train error 0.00,  test loss 5.086040, test error 54.65
# Epoch   800, train loss 0.001643, train error 0.00,  test loss 5.219321, test error 54.65
# Epoch   900, train loss 0.001389, train error 0.00,  test loss 5.332689, test error 54.55
# Training model with  90 hidden variables
# Epoch     0, train loss 2.003862, train error 74.10,  test loss 1.926096, test error 74.62
# Epoch   100, train loss 0.128906, train error 0.82,  test loss 2.304305, test error 51.45
# Epoch   200, train loss 0.014255, train error 0.00,  test loss 3.372101, test error 52.45
# Epoch   300, train loss 0.006372, train error 0.00,  test loss 3.828294, test error 52.50
# Epoch   400, train loss 0.003915, train error 0.00,  test loss 4.100986, test error 52.55
# Epoch   500, train loss 0.002751, train error 0.00,  test loss 4.296127, test error 52.58
# Epoch   600, train loss 0.002095, train error 0.00,  test loss 4.451138, test error 52.78
# Epoch   700, train loss 0.001676, train error 0.00,  test loss 4.579255, test error 52.72
# Epoch   800, train loss 0.001388, train error 0.00,  test loss 4.686380, test error 52.75
# Epoch   900, train loss 0.001179, train error 0.00,  test loss 4.780576, test error 52.78
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015584, train error 74.60,  test loss 1.954006, test error 75.78
# Epoch   100, train loss 0.092633, train error 0.20,  test loss 2.369254, test error 52.22
# Epoch   200, train loss 0.012403, train error 0.00,  test loss 3.317790, test error 52.67
# Epoch   300, train loss 0.005770, train error 0.00,  test loss 3.713715, test error 52.80
# Epoch   400, train loss 0.003607, train error 0.00,  test loss 3.962883, test error 52.75
# Epoch   500, train loss 0.002567, train error 0.00,  test loss 4.145093, test error 52.72
# Epoch   600, train loss 0.001968, train error 0.00,  test loss 4.285986, test error 52.83
# Epoch   700, train loss 0.001583, train error 0.00,  test loss 4.403881, test error 52.90
# Epoch   800, train loss 0.001314, train error 0.00,  test loss 4.503084, test error 52.97
# Epoch   900, train loss 0.001119, train error 0.00,  test loss 4.589825, test error 52.85
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975900, train error 72.10,  test loss 1.902649, test error 73.30
# Epoch   100, train loss 0.051461, train error 0.00,  test loss 2.250033, test error 50.75
# Epoch   200, train loss 0.009586, train error 0.00,  test loss 2.921021, test error 51.08
# Epoch   300, train loss 0.004762, train error 0.00,  test loss 3.215245, test error 51.08
# Epoch   400, train loss 0.003047, train error 0.00,  test loss 3.400520, test error 51.03
# Epoch   500, train loss 0.002195, train error 0.00,  test loss 3.542076, test error 51.17
# Epoch   600, train loss 0.001696, train error 0.00,  test loss 3.651412, test error 51.30
# Epoch   700, train loss 0.001370, train error 0.00,  test loss 3.741575, test error 51.40
# Epoch   800, train loss 0.001144, train error 0.00,  test loss 3.819585, test error 51.30
# Epoch   900, train loss 0.000977, train error 0.00,  test loss 3.887074, test error 51.33
# Training model with 140 hidden variables
# Epoch     0, train loss 1.953503, train error 71.55,  test loss 1.858839, test error 71.53
# Epoch   100, train loss 0.037168, train error 0.00,  test loss 2.202701, test error 50.10
# Epoch   200, train loss 0.008184, train error 0.00,  test loss 2.697993, test error 50.30
# Epoch   300, train loss 0.004178, train error 0.00,  test loss 2.934587, test error 50.42
# Epoch   400, train loss 0.002714, train error 0.00,  test loss 3.089576, test error 50.42
# Epoch   500, train loss 0.001973, train error 0.00,  test loss 3.206397, test error 50.42
# Epoch   600, train loss 0.001531, train error 0.00,  test loss 3.297405, test error 50.42
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.373158, test error 50.35
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.438153, test error 50.55
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.495535, test error 50.47
# Training model with 160 hidden variables
# Epoch     0, train loss 1.967925, train error 73.20,  test loss 1.882201, test error 73.62
# Epoch   100, train loss 0.029543, train error 0.00,  test loss 2.238625, test error 50.53
# Epoch   200, train loss 0.007261, train error 0.00,  test loss 2.681913, test error 50.60
# Epoch   300, train loss 0.003821, train error 0.00,  test loss 2.897958, test error 50.33
# Epoch   400, train loss 0.002507, train error 0.00,  test loss 3.041780, test error 50.28
# Epoch   500, train loss 0.001837, train error 0.00,  test loss 3.149035, test error 50.28
# Epoch   600, train loss 0.001434, train error 0.00,  test loss 3.234152, test error 50.25
# Epoch   700, train loss 0.001168, train error 0.00,  test loss 3.305138, test error 50.28
# Epoch   800, train loss 0.000981, train error 0.00,  test loss 3.365990, test error 50.35
# Epoch   900, train loss 0.000842, train error 0.00,  test loss 3.419151, test error 50.42
# Training model with 180 hidden variables
# Epoch     0, train loss 1.930300, train error 70.18,  test loss 1.848386, test error 70.53
# Epoch   100, train loss 0.023885, train error 0.00,  test loss 2.124258, test error 49.53
# Epoch   200, train loss 0.006569, train error 0.00,  test loss 2.494948, test error 49.58
# Epoch   300, train loss 0.003521, train error 0.00,  test loss 2.682390, test error 49.58
# Epoch   400, train loss 0.002332, train error 0.00,  test loss 2.804725, test error 49.67
# Epoch   500, train loss 0.001716, train error 0.00,  test loss 2.898373, test error 49.65
# Epoch   600, train loss 0.001344, train error 0.00,  test loss 2.971494, test error 49.62
# Epoch   700, train loss 0.001097, train error 0.00,  test loss 3.032171, test error 49.75
# Epoch   800, train loss 0.000923, train error 0.00,  test loss 3.085353, test error 49.70
# Epoch   900, train loss 0.000793, train error 0.00,  test loss 3.131405, test error 49.78
# Training model with 200 hidden variables
# Epoch     0, train loss 1.936869, train error 70.38,  test loss 1.826028, test error 70.47
# Epoch   100, train loss 0.021583, train error 0.00,  test loss 2.077185, test error 48.85
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.410455, test error 48.65
# Epoch   300, train loss 0.003307, train error 0.00,  test loss 2.582829, test error 48.85
# Epoch   400, train loss 0.002206, train error 0.00,  test loss 2.695934, test error 48.85
# Epoch   500, train loss 0.001629, train error 0.00,  test loss 2.783803, test error 48.90
# Epoch   600, train loss 0.001280, train error 0.00,  test loss 2.853617, test error 48.88
# Epoch   700, train loss 0.001047, train error 0.00,  test loss 2.911824, test error 48.78
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.961702, test error 48.90
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 3.005482, test error 48.83
# Training model with 250 hidden variables
# Epoch     0, train loss 1.924127, train error 70.95,  test loss 1.835290, test error 72.18
# Epoch   100, train loss 0.017092, train error 0.00,  test loss 1.985941, test error 49.70
# Epoch   200, train loss 0.005374, train error 0.00,  test loss 2.251298, test error 49.35
# Epoch   300, train loss 0.002997, train error 0.00,  test loss 2.389441, test error 49.40
# Epoch   400, train loss 0.002023, train error 0.00,  test loss 2.483246, test error 49.30
# Epoch   500, train loss 0.001506, train error 0.00,  test loss 2.555136, test error 49.35
# Epoch   600, train loss 0.001189, train error 0.00,  test loss 2.612962, test error 49.40
# Epoch   700, train loss 0.000976, train error 0.00,  test loss 2.660794, test error 49.28
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.702935, test error 49.28
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.739357, test error 49.33
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873114, train error 67.55,  test loss 1.781343, test error 68.32
# Epoch   100, train loss 0.014601, train error 0.00,  test loss 1.909797, test error 47.40
# Epoch   200, train loss 0.004823, train error 0.00,  test loss 2.141850, test error 47.08
# Epoch   300, train loss 0.002733, train error 0.00,  test loss 2.265718, test error 46.97
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.350526, test error 46.83
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.416548, test error 46.92
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.469610, test error 46.97
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.513725, test error 46.95
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.552014, test error 47.00
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.585772, test error 46.97
# Training model with 400 hidden variables
# Epoch     0, train loss 1.878406, train error 67.12,  test loss 1.819662, test error 71.22
# Epoch   100, train loss 0.011335, train error 0.00,  test loss 1.869176, test error 47.35
# Epoch   200, train loss 0.004082, train error 0.00,  test loss 2.062998, test error 47.53
# Epoch   300, train loss 0.002367, train error 0.00,  test loss 2.170561, test error 47.38
# Epoch   400, train loss 0.001632, train error 0.00,  test loss 2.244555, test error 47.38
# Epoch   500, train loss 0.001231, train error 0.00,  test loss 2.301907, test error 47.45
# Epoch   600, train loss 0.000980, train error 0.00,  test loss 2.347824, test error 47.47
# Epoch   700, train loss 0.000810, train error 0.00,  test loss 2.386815, test error 47.58
# Epoch   800, train loss 0.000688, train error 0.00,  test loss 2.420364, test error 47.47
# Epoch   900, train loss 0.000596, train error 0.00,  test loss 2.449999, test error 47.45

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
